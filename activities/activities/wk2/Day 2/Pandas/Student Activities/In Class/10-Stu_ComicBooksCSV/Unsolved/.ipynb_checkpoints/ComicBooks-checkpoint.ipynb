# %%
# Import Dependencies
import pandas as pd

# %%
# Make a reference to the comic_books_expanded.csv file path
pat = 'Resources/comic_books_expanded.csv'
df = pd.read_csv(pat)
df.head()
# Import the comic_books_expanded.csv file as a DataFrame
# Check the special characters imported correctly
# Out:
#                                                Title  \
# 0    #$@&! : the official Lloyd Llewellyn collection
# 1  #WhatDoYouSee? : a graphic novel anthology of ...
# 2                                 #takebacktheshield
# 3       '68. Volume 1. Better run through the jungle
# 4                                   'Bots of science
#
#                                         Other titles  BL record ID  \
# 0                Official Lloyd Llewellyn collection      10989363
# 1                                                NaN      19185604
# 2                                                NaN      18247558
# 3                      Better run through the jungle      16039698
# 4  Trans formers ; Trans formers animated : bots ...      15619333
#
#   Type of resource                            Content type Material type  \
# 0        Monograph                Language material ; Text        Volume
# 1        Monograph  Language material ; Still image ; Text        Volume
# ...

# %%
# Remove unecessary columns from the DataFrame and save the new DataFrame
cleaned = df[['ISBN', 'Title', 'Other titles', 'Name', 'Publisher', 'All names', 'Country of publication', 'Place of publication', 'Date of publication']]
cleaned
# Only keep: "ISBN", "Title", "Other titles", "Name", "All names", 
# "Country of publication", "Place of publication", "Publisher", "Date of publication"
# Out:
#                 ISBN                                              Title  \
# 0      9780930193904    #$@&! : the official Lloyd Llewellyn collection
# 1      9780992664220  #WhatDoYouSee? : a graphic novel anthology of ...
# 2      9781302903299                                 #takebacktheshield
# 3      9781607065166       '68. Volume 1. Better run through the jungle
# 4      9781600107672                                   'Bots of science
# ...              ...                                                ...
# 28687  9780805094886                                               مترو
# 28688  9781569708354                                    丘の上の楽園. English
# 28689  9781891830914                                       信じられない変更ロボット
# 28690  9787222155145                                            喜欢我也没关系
# 28691  9789810422134                                     幻猪TKG千禧年之章 : 糕
#
#                                             Other titles              Name  \
# ...

# %%
# Rename the headers to be more explanatory
cleaned = cleaned.rename(columns={'Country of publication':'Country', 'Place of publication':'City', 'Date of publication':'Year'})
cleaned
# Out:
#                 ISBN                                              Title  \
# 0      9780930193904    #$@&! : the official Lloyd Llewellyn collection
# 1      9780992664220  #WhatDoYouSee? : a graphic novel anthology of ...
# 2      9781302903299                                 #takebacktheshield
# 3      9781607065166       '68. Volume 1. Better run through the jungle
# 4      9781600107672                                   'Bots of science
# ...              ...                                                ...
# 28687  9780805094886                                               مترو
# 28688  9781569708354                                    丘の上の楽園. English
# 28689  9781891830914                                       信じられない変更ロボット
# 28690  9787222155145                                            喜欢我也没关系
# 28691  9789810422134                                     幻猪TKG千禧年之章 : 糕
#
#                                             Other titles              Name  \
# ...

# %%
# Push the remade DataFrame to a new CSV file

# %%
cleaned.to_csv('Output/output.csv')
